# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing packages
import seaborn as sns

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# Sử dụng cả Matplotlib và Seaborn cùng nhau là một quá trình rất đơn giản. Chúng ta chỉ cần gọi hàm Seaborn Plotting như bình thường và sau đó có thể sử dụng chức năng tùy chỉnh của Matplotlib

# %% [markdown]
# Phương thức set_style() được sử dụng để thiết lập tính thẩm mỹ của cốt truyện. Điều đó có nghĩa là nó ảnh hưởng đến những thứ như màu sắc của các trục, lưới có hoạt động hay không hoặc các yếu tố thẩm mỹ khác. Có năm chủ đề có sẵn trong Seaborn.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')

plt.show()

# %% [markdown]
# Gai là các đường ghi ranh giới dữ liệu và nối các dấu trục. Nó có thể được loại bỏ bằng phương thức despine().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# setting the x limit of the plot
plt.xlim(5)

plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# changing the theme to dark
sns.set_style("dark")
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# Removing the spines
sns.despine()
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# changing the figure size
plt.figure(figsize = (2, 4))

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# Removing the spines
sns.despine()

plt.show()

# %% [markdown]
# # bài này của Nguyễn Quốc Đạt

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# Setting the scale of the plot
sns.set_context("paper")

plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")


def plot():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)

with sns.axes_style('darkgrid'):

    # Adding the subplot
    plt.subplot(211)
    plot()

plt.subplot(212)
plot()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# current colot palette
palette = sns.color_palette()

# plots the color palette as a
# horizontal array
sns.palplot(palette)

plt.show()

# %% [markdown]
# Loại bảng màu này sử dụng hai màu khác nhau, trong đó mỗi màu mô tả các điểm khác nhau, từ một điểm chung theo một trong hai hướng. Hãy xem xét phạm vi từ -10 đến 10 để giá trị từ -10 đến 0 lấy một màu và các giá trị từ 0 đến 10 lấy một màu khác.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# current colot palette
palette = sns.color_palette('PiYG', 11)

# diverging color palette
sns.palplot(palette)

plt.show()

# %% [markdown]
# Bảng màu tuần tự được sử dụng khi phạm vi phân phối từ giá trị thấp hơn đến giá trị cao hơn. Để thực hiện việc này, hãy thêm ký tự 's' vào màu được truyền trong bảng màu.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# current colot palette
palette = sns.color_palette('Greens', 11)

# sequential color palette
sns.palplot(palette)

plt.show()

# %% [markdown]
# Phương thức set_palette() được sử dụng để đặt bảng màu mặc định cho tất cả các ô. Các đối số cho cả color_palette() và set_palette() đều giống nhau. set_palette() thay đổi các tham số matplotlib mặc định.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

def plot():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# setting the default color palette
sns.set_palette('vlag')
plt.subplot(211)

# plotting with the color palette
# as vlag
plot()

# setting another default color palette
sns.set_palette('Accent')
plt.subplot(212)
plot()

plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


# loading dataset
data = sns.load_dataset("iris")

def graph():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# Creating a new figure with width = 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4))

# Creating first axes for the figure
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# plotting the graph
graph()

# Creating second axes for the figure
ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])

# plotting the graph
graph()

plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

def graph():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# Adding the subplot at the specified
# grid position
plt.subplot(121)
graph()

# Adding the subplot at the specified
# grid position
plt.subplot(122)
graph()

plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

def graph():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)

# adding the subplots
axes1 = plt.subplot2grid (
  (7, 1), (0, 0), rowspan = 2,  colspan = 1)
graph()

axes2 = plt.subplot2grid (
  (7, 1), (2, 0), rowspan = 2, colspan = 1)
graph()

axes3 = plt.subplot2grid (
  (7, 1), (4, 0), rowspan = 2, colspan = 1)
graph()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

plot = sns.FacetGrid(data, col="species")
plot.map(plt.plot, "sepal_width")

plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("flights")

plot = sns.PairGrid(data)
plot.map(plt.plot)

plt.show()

# %% [markdown]
# # bài này của Nguyễn Quốc Đạt

# %% [markdown]
# Hàm này cung cấp cho chúng ta quyền truy cập vào một số hàm cấp trục khác nhau hiển thị mối quan hệ giữa hai biến với ánh xạ ngữ nghĩa của các tập hợp con. Nó được vẽ bằng phương thức replot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

# creating the relplot
sns.relplot(x='sepal_width', y='species', data=data)

plt.show()

# %% [markdown]
# Biểu đồ phân tán là nền tảng chính của trực quan hóa thống kê. Nó mô tả sự phân bố chung của hai biến bằng cách sử dụng một đám mây điểm, trong đó mỗi điểm đại diện cho một quan sát trong tập dữ liệu. Mô tả này cho phép mắt suy ra một lượng thông tin đáng kể về việc liệu có bất kỳ mối quan hệ có ý nghĩa nào giữa chúng hay không. Nó được vẽ bằng phương thức Scatterplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.scatterplot(x='sepal_length', y='sepal_width', data=data)
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.lineplot(x='sepal_length', y='species', data=data)
plt.show()

# %% [markdown]
# # bài này của Nguyễn Quốc Đạt

# %% [markdown]
# Barplot về cơ bản được sử dụng để tổng hợp dữ liệu phân loại theo một số phương pháp và theo mặc định, nó là giá trị trung bình. Nó cũng có thể hiểu là sự hình dung của nhóm bằng hành động. Để sử dụng biểu đồ này, chúng tôi chọn một cột phân loại cho trục x và một cột số cho trục y và chúng tôi thấy rằng nó tạo ra một biểu đồ lấy giá trị trung bình trên mỗi cột phân loại. Nó có thể được tạo bằng phương thức barplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.barplot(x='species', y='sepal_length', data=data)
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.countplot(x='species', data=data)
plt.show()

# %% [markdown]
# Lô hộp
#
# Biểu đồ hộp đôi khi còn được gọi là biểu đồ hộp và râu. Nó cho thấy sự phân bố của dữ liệu định lượng thể hiện sự so sánh giữa các biến. boxplot hiển thị các phần tư của tập dữ liệu trong khi các phần râu mở rộng để hiển thị phần còn lại của phân phối, tức là các dấu chấm biểu thị sự hiện diện của các giá trị ngoại lệ. Nó được tạo bằng phương thức boxplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.boxplot(x='species', y='sepal_width', data=data)
plt.show()

# %% [markdown]
# Violinplot
# Nó tương tự như boxplot ngoại trừ việc nó cung cấp khả năng hiển thị cao hơn, nâng cao hơn và sử dụng ước tính mật độ hạt nhân để đưa ra mô tả tốt hơn về phân phối dữ liệu. Nó được tạo bằng phương thức violinplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.violinplot(x='species', y='sepal_width', data=data)
plt.show()

# %% [markdown]
# Về cơ bản, nó tạo ra một biểu đồ phân tán dựa trên danh mục. Nó được tạo bằng phương thức Stripplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.stripplot(x='species', y='sepal_width', data=data)
plt.show()

# %% [markdown]
# Swamplot rất giống với Stripplot ngoại trừ việc các điểm được điều chỉnh sao cho không trùng nhau. Một số người cũng thích kết hợp ý tưởng về một âm mưu violin và một âm mưu thoát y để tạo thành cốt truyện này. Một nhược điểm của việc sử dụng Swampplot là đôi khi chúng không có khả năng mở rộng tốt với số lượng thực sự lớn và cần rất nhiều tính toán để sắp xếp chúng. Vì vậy, trong trường hợp chúng ta muốn hình dung một sơ đồ bầy đàn một cách chính xác, chúng ta có thể vẽ nó lên trên một biểu đồ violin. Nó được vẽ bằng phương thức Swampplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.swarmplot(x='species', y='sepal_width', data=data)
plt.show()

# %% [markdown]
# Factorplot là biểu đồ tổng quát nhất trong số tất cả các biểu đồ này và cung cấp một tham số gọi là loại để chọn loại biểu đồ mà chúng ta muốn, do đó giúp chúng ta tránh khỏi rắc rối khi viết các biểu đồ này một cách riêng biệt. Tham số loại có thể là bar, violin, bầy đàn, v.v. Nó được vẽ bằng phương thức Factorplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.factorplot(x='species', y='sepal_width', data=data)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # bài này của Nguyễn Quốc Đạt

# %% [markdown]
# Biểu đồ về cơ bản được sử dụng để biểu diễn dữ liệu được cung cấp dưới dạng một số nhóm. Đây là phương pháp chính xác để biểu diễn đồ họa của phân phối dữ liệu số. Nó có thể được vẽ bằng hàm histplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.histplot(x='species', y='sepal_width', data=data)
plt.show()

# %% [markdown]
# Distplot về cơ bản được sử dụng cho tập hợp các quan sát đơn biến và hiển thị nó thông qua biểu đồ, tức là chỉ một quan sát và do đó chúng tôi chọn một cột cụ thể của tập dữ liệu. Nó được trồng trong chậu bằng phương thức distplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.distplot(data['sepal_width'])
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Jointplot is used to draw a plot of two variables with bivariate and univariate graphs. It basically combines two different plots. It is plotted using the jointplot() method.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.jointplot(x='species', y='sepal_width', data=data)
plt.show()

# %% [markdown]
# Pairplot biểu thị mối quan hệ theo cặp trên toàn bộ khung dữ liệu và hỗ trợ một đối số bổ sung gọi là màu sắc để phân tách theo phân loại. Về cơ bản, những gì nó làm là tạo một biểu đồ chung giữa mọi cột số có thể có và sẽ mất một khoảng thời gian nếu khung dữ liệu thực sự lớn. Nó được vẽ bằng phương thức pairplot().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.pairplot(data=data, hue='species')
plt.show()

# %% [markdown]
# Rugplot vẽ các điểm dữ liệu trong một mảng dưới dạng các thanh trên một trục. Giống như một biểu đồ phân phối, nó có một cột duy nhất. Thay vì vẽ biểu đồ, nó tạo ra các dấu gạch ngang trên toàn bộ cốt truyện. Nếu bạn so sánh nó với joinplot, bạn có thể thấy rằng chức năng của Jointplot là nó đếm các dấu gạch ngang và hiển thị dưới dạng thùng. Nó được vẽ bằng phương thức rugplot().

# %% [markdown]
# # bài này của Nguyễn Quốc Đạt

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.rugplot(data=data)
plt.show()

# %% [markdown]
# Biểu đồ KDE được mô tả là Ước tính mật độ hạt nhân được sử dụng để trực quan hóa Mật độ xác suất của một biến liên tục. Nó mô tả mật độ xác suất ở các giá trị khác nhau trong một biến liên tục. Chúng tôi cũng có thể vẽ một biểu đồ cho nhiều mẫu, giúp hiển thị dữ liệu hiệu quả hơn.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.kdeplot(x='sepal_length', y='sepal_width', data=data)
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("tips")

sns.lmplot(x='total_bill', y='tip', data=data)
plt.show()

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("tips")

sns.regplot(x='total_bill', y='tip', data=data)
plt.show()

# %% [markdown]
# # bài này của Nguyễn Quốc Đạt

# %% [markdown]
# Heatmap được định nghĩa là biểu diễn đồ họa của dữ liệu bằng cách sử dụng màu sắc để trực quan hóa giá trị của ma trận. Trong đó, để biểu thị các giá trị phổ biến hơn hoặc hoạt động cao hơn, màu sáng hơn về cơ bản được sử dụng màu đỏ và để biểu thị các giá trị hoạt động hoặc ít phổ biến hơn, màu tối hơn được ưu tiên. nó có thể được vẽ bằng hàm heatmap().

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("tips")

# correlation between the different parameters
tc = data.corr()

sns.heatmap(tc)
plt.show()

# %% [markdown]
# Hàm clustermap() của seaborn vẽ sơ đồ nhiệt được phân cụm theo cấp bậc của tập dữ liệu ma trận đã cho. Phân cụm đơn giản có nghĩa là nhóm dữ liệu dựa trên mối quan hệ giữa các biến trong dữ liệu.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("tips")

# correlation between the different parameters
tc = data.corr()

sns.clustermap(tc)
plt.show()
